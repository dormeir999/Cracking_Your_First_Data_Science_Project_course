# %%
import os

try:
    os.chdir("src")
except:
    pass

os.getcwd()
# Out:
# 'C:\\Users\\dor.meir\\OneDrive - Qualitest Group\\Documents\\Courses\\Educative\\Cracking your first Data Science project\\src'

# %% [markdown]
# # Training

# %%
# %run utils
# Out:
# main()
# import_data()
# Attempting to load data from: C:\Users\dor.meir\OneDrive - Qualitest Group\Documents\Courses\Educative\Cracking your first Data Science project\data/raw/winequalityN.csv
# Data imported successfully!
# transform_numeric_target_feature_to_binary()
# split_dataset()
# test_if_features_statistically_different()
# test_if_significant()
# test_if_significant()
# test_if_significant()
# test_if_significant()
# test_if_significant()
# test_if_significant()
# test_if_significant()
# test_if_significant()
# test_if_significant()
# test_if_significant()
# test_if_significant()
# test_if_significant()
# test_if_significant()
# test_if_significant()
# test_if_significant()
# test_if_significant()
# test_if_significant()
# test_if_significant()
# test_if_significant()
# test_if_significant()
# test_if_significant()
# test_if_significant()
# test_if_significant()
# test_if_significant()
# test_if_significant()
# test_if_significant()
# test_if_significant()
# ...
